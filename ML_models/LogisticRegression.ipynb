# %%
import numpy as np

# %%
import numpy as np

# Dataset
X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

y = np.array([0,0,0,1])

# Sigmoid
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Parameters
weights = np.zeros(X.shape[1])
bias = 0

# Training
learning_rate = 0.1
epochs = 1000
m = len(X)

for epoch in range(epochs):

    z = np.dot(X, weights) + bias

    y_pred = sigmoid(z)

    dw = (1/m) * np.dot(X.T, (y_pred - y))
    db = (1/m) * np.sum(y_pred - y)

    weights -= learning_rate * dw
    bias -= learning_rate * db

# Prediction
def predict(X):

    z = np.dot(X, weights) + bias

    probs = sigmoid(z)

    return (probs >= 0.5).astype(int)

print("Weights:", weights)
print("Bias:", bias)

print("Predictions:", predict(X))
# Out:
# Weights: [3.03763559 3.03763559]
# Bias: -4.773702236905248
# Predictions: [0 0 0 1]
