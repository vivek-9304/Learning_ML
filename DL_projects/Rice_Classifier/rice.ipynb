# %%
# import kagglehub

# # Download latest version
# path = kagglehub.dataset_download("muratkokludataset/rice-image-dataset")

# print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\vivek\.cache\kagglehub\datasets\muratkokludataset\rice-image-dataset\1.archive...
# 100%|██████████| 219M/219M [00:22<00:00, 10.3MB/s]
# Extracting files...
# Path to dataset files: C:\Users\vivek\.cache\kagglehub\datasets\muratkokludataset\rice-image-dataset\versions\1

# %%
import pandas as pd
import torch
