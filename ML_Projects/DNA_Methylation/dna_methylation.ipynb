# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Learning_ML\\ML_Projects\\DNA_Methylation\\dna.csv")
print(data.head())
# Out:
#    cpg_density  genomic_location  regulatory_score  conservation_score  \
# 0     0.799343          0.949839          0.297447            0.268438
# 1     0.672347          0.831158          0.456644            0.477923
# 2     0.829538          0.614908          0.262274            0.567279
# 3     1.000000          0.438266          0.407612            1.000000
# 4     0.653169          0.774556          0.000000            0.761311
#
#    methylation_status
# 0                   1
# 1                   1
# 2                   0
# 3                   1
# 4                   0

# %%
data.describe()
# Out:
#        cpg_density  genomic_location  regulatory_score  conservation_score  \
# count  1000.000000       1000.000000       1000.000000         1000.000000
# mean      0.697508          0.611986          0.501159            0.643147
# std       0.183028          0.234104          0.270085            0.198944
# min       0.051747          0.000000          0.000000            0.064110
# 25%       0.570482          0.448440          0.305600            0.502516
# 50%       0.705060          0.615769          0.499925            0.650037
# 75%       0.829589          0.782221          0.698275            0.783389
# max       1.000000          1.000000          1.000000            1.000000
#
#        methylation_status
# count         1000.000000
# mean             0.554000
# std              0.497324
# min              0.000000
# 25%              0.000000
# 50%              1.000000
# 75%              1.000000
# max              1.000000
